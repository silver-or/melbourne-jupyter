# %%
import matplotlib.pylab as plt

import tensorflow as tf

# %%
pip install --user tf-nightly
# Out:
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
#   WARNING: The script f2py.exe is installed in 'C:\Users\bitcamp\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\bitcamp\\AppData\\Roaming\\Python\\Python39\\site-packages\\~=mpy\\.libs\\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll'
# Check the permissions.
#
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# Requirement already satisfied: tf-nightly in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (2.10.0.dev20220628)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (0.26.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.1.0)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.1.0-py3-none-any.whl (123 kB)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.46.3)
# Requirement already satisfied: packaging in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (21.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (3.7.4.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (14.0.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (0.2.0)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (61.2.0)
# Requirement already satisfied: tf-estimator-nightly~=2.10.0.dev in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (2.10.0.dev2022062908)
# Requirement already satisfied: keras-nightly~=2.10.0.dev in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (2.10.0.dev2022062807)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.15.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (0.4.0)
# Collecting numpy>=1.20
#   Using cached numpy-1.23.0-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (3.19.4)
# Requirement already satisfied: tb-nightly~=2.10.0.a in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (2.10.0a20220628)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.12.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from astunparse>=1.6.0->tf-nightly) (0.35.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.24.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.33.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from packaging->tf-nightly) (3.0.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tb-nightly~=2.10.0.a->tf-nightly) (4.11.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tb-nightly~=2.10.0.a->tf-nightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (3.2.0)
# Installing collected packages: flatbuffers, numpy, absl-py
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# Requirement already satisfied: tf-nightly in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (2.10.0.dev20220628)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.23.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.46.3)
# Requirement already satisfied: keras-nightly~=2.10.0.dev in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (2.10.0.dev2022062807)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (3.19.4)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (3.1.0)
# Requirement already satisfied: setuptools in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (61.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (0.2.0)
# Requirement already satisfied: tf-estimator-nightly~=2.10.0.dev in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (2.10.0.dev2022062908)
# Requirement already satisfied: six>=1.12.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.15.0)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.1.0-py3-none-any.whl (123 kB)
# Requirement already satisfied: tb-nightly~=2.10.0.a in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (2.10.0a20220628)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (0.26.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (3.7.4.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (14.0.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tf-nightly) (1.6.3)
# Requirement already satisfied: packaging in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tf-nightly) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from astunparse>=1.6.0->tf-nightly) (0.35.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.33.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from tb-nightly~=2.10.0.a->tf-nightly) (2.24.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from packaging->tf-nightly) (3.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\bitcamp\.conda\envs\crp\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tb-nightly~=2.10.0.a->tf-nightly) (4.11.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tb-nightly~=2.10.0.a->tf-nightly) (2.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tb-nightly~=2.10.0.a->tf-nightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly~=2.10.0.a->tf-nightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bitcamp\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly~=2.10.0.a->tf-nightly) (3.2.0)
# Installing collected packages: absl-py
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.15.0
#     Uninstalling absl-py-0.15.0:
#       Successfully uninstalled absl-py-0.15.0
# Successfully installed absl-py-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires absl-py~=0.10, but you have absl-py 1.1.0 which is incompatible.
# tensorflow 2.6.0 requires flatbuffers~=1.12.0, but you have flatbuffers 2.0 which is incompatible.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 1.23.0 which is incompatible.
# tensorflow-gpu 2.6.2 requires absl-py~=0.10, but you have absl-py 1.1.0 which is incompatible.
# tensorflow-gpu 2.6.2 requires flatbuffers~=1.12.0, but you have flatbuffers 2.0 which is incompatible.
# tensorflow-gpu 2.6.2 requires numpy~=1.19.2, but you have numpy 1.23.0 which is incompatible.
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\bitcamp\appdata\roaming\python\python39\site-packages)

# %%
import tensorflow_hub as hub

from tensorflow.keras import layers

# %%
classifier_url ="https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/2"

# %%
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer(classifier_url, input_shape=IMAGE_SHAPE+(3,))
])

# %%
import numpy as np
import PIL.Image as Image

grace_hopper = tf.keras.utils.get_file('image.jpg','https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg')
grace_hopper = Image.open(grace_hopper).resize(IMAGE_SHAPE)
grace_hopper
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg
# 65536/61306 [================================] - 0s 0us/step
# 73728/61306 [====================================] - 0s 0us/step
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1FB5F2654C0>

# %%
grace_hopper = np.array(grace_hopper)/255.0
grace_hopper.shape
# Out:
# (224, 224, 3)

# %%
result = classifier.predict(grace_hopper[np.newaxis, ...])
result.shape
# Out:
# (1, 1001)

# %%
predicted_class = np.argmax(result[0], axis=-1)
predicted_class
# Out:
# 653

# %%
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
imagenet_labels = np.array(open(labels_path).read().splitlines())
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt
# 16384/10484 [==============================================] - 0s 0s/step
# 24576/10484 [======================================================================] - 0s 0us/step

# %%
plt.imshow(grace_hopper)
plt.axis('off')
predicted_class_name = imagenet_labels[predicted_class]
_ = plt.title("Prediction: " + predicted_class_name.title())

# %%
data_root = tf.keras.utils.get_file(
  'flower_photos','https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
   untar=True)

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
image_data = image_generator.flow_from_directory(str(data_root), target_size=IMAGE_SHAPE)
# Out:
# Found 3670 images belonging to 5 classes.

# %%
for image_batch, label_batch in image_data:
  print("Image batch shape: ", image_batch.shape)
  print("Label batch shape: ", label_batch.shape)
  break
# Out:
# Image batch shape:  (32, 224, 224, 3)
# Label batch shape:  (32, 5)

# %%
result_batch = classifier.predict(image_batch)
result_batch.shape
# Out:
# (32, 1001)

# %%
predicted_class_names = imagenet_labels[np.argmax(result_batch, axis=-1)]
predicted_class_names
# Out:
# array(['daisy', 'greenhouse', 'mushroom', 'vase', 'barn spider', 'daisy',
#        'plate', 'daisy', 'coral fungus', 'sulphur butterfly', 'daisy',
#        'cardoon', 'pot', 'cardoon', 'daisy', 'cardoon', 'daisy', 'daisy',
#        'vase', 'daisy', 'daisy', 'daisy', 'cauliflower', 'daisy',
#        'feather boa', 'coral reef', 'mushroom', 'bee', 'daisy',
#        'park bench', 'cardoon', 'feather boa'], dtype='<U30')

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  plt.title(predicted_class_names[n])
  plt.axis('off')
_ = plt.suptitle("ImageNet predictions")

# %%
feature_extractor_url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/2"

# %%
feature_extractor_layer = hub.KerasLayer(feature_extractor_url,
                                         input_shape=(224,224,3))

# %%
feature_batch = feature_extractor_layer(image_batch)
print(feature_batch.shape)
# Out:
# (32, 1280)

# %%
feature_batch = feature_extractor_layer(image_batch)
print(feature_batch.shape)
# Out:
# (32, 1280)

# %%
feature_extractor_layer.trainable = False

# %%
model = tf.keras.Sequential([
  feature_extractor_layer,
  layers.Dense(image_data.num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_1 (KerasLayer)   (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 5)                 6405
# =================================================================
# Total params: 2,264,389
# Trainable params: 6,405
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
predictions = model(image_batch)

# %%
predictions.shape
# Out:
# TensorShape([32, 5])

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(),
  loss='categorical_crossentropy',
  metrics=['acc'])

# %%
class CollectBatchStats(tf.keras.callbacks.Callback):
  def __init__(self):
    self.batch_losses = []
    self.batch_acc = []

  def on_train_batch_end(self, batch, logs=None):
    self.batch_losses.append(logs['loss'])
    self.batch_acc.append(logs['acc'])
    self.model.reset_metrics()

# %%
steps_per_epoch = np.ceil(image_data.samples/image_data.batch_size)

batch_stats_callback = CollectBatchStats()

history = model.fit_generator(image_data, epochs=2,
                              steps_per_epoch=steps_per_epoch,
                              callbacks = [batch_stats_callback])
# Out:
# C:\Users\bitcamp\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/2
# 115/115 [==============================] - 13s 97ms/step - loss: 0.4118 - acc: 0.8438
# Epoch 2/2
# 115/115 [==============================] - 8s 71ms/step - loss: 0.3278 - acc: 0.9062

# %%
plt.figure()
plt.ylabel("Loss")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(batch_stats_callback.batch_losses)

# %%
plt.figure()
plt.ylabel("Accuracy")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(batch_stats_callback.batch_acc)

# %%
class_names = sorted(image_data.class_indices.items(), key=lambda pair:pair[1])
class_names = np.array([key.title() for key, value in class_names])
class_names
# Out:
# array(['Daisy', 'Dandelion', 'Roses', 'Sunflowers', 'Tulips'],
#       dtype='<U10')

# %%
predicted_batch = model.predict(image_batch)
predicted_id = np.argmax(predicted_batch, axis=-1)
predicted_label_batch = class_names[predicted_id]

# %%
label_id = np.argmax(label_batch, axis=-1)

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  color = "green" if predicted_id[n] == label_id[n] else "red"
  plt.title(predicted_label_batch[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (green: correct, red: incorrect)")

# %%
import time
t = time.time()

export_path = "/tmp/saved_models/{}".format(int(t))
model.save(export_path, save_format='tf')

export_path
# Out:
# INFO:tensorflow:Assets written to: /tmp/saved_models/1656499661\assets
# INFO:tensorflow:Assets written to: /tmp/saved_models/1656499661\assets
# '/tmp/saved_models/1656499661'

# %%
reloaded = tf.keras.models.load_model(export_path)

# %%
result_batch = model.predict(image_batch)
reloaded_result_batch = reloaded.predict(image_batch)

# %%
abs(reloaded_result_batch - result_batch).max()
# Out:
# 0.0
